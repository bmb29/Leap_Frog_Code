# %%
using PyCall
# pygui(:qt)
using PyPlot
# pygui(true)
using PolynomialRoots
include("Q1_trajectories.jl")
include("escape_dimer.jl")
include("forward_one.jl")
include("back_one.jl")
using .escape_dimer
t_end=1e5
H=.25;
# Out:
# WARNING: replacing module escape_dimer.

# %%
Q=.95
P=.65;
@time escape_dimer.escape_exit_num_dimer([Q,P],t_end,H)
# Out:
#   0.057279 seconds (3.03 M allocations: 69.399 MiB, 49.06% gc time)
# (3.0, 1.0, [6.866269875952604, 6.866269875952604, 22.468577952673325, 22.468577952673325, 61.22169678118865, 61.22169678118865, 69.16017704629883, 69.16017704629883], [4.700761291675042, 4.700761291675042, 37.08364361326113, 37.08364361326113])

# %%
figure()
Tf,Qf,hit_f,Tb,Qb,hit_b=Q1_trajectories(Q,P,t_end,H,true)
println(hit_f)
println(hit_b)

plot(Tf,Qf)
plot(-Tb,Qb)
Tfp,Qfp,hit_f,Tbp,Qbp,hit_b=Q1_trajectories(Q,P,t_end,H,false)
println(hit_f)
println(hit_b)   


plot(Tfp,Qfp,".")
plot(-Tbp,Qbp,".");
# println(escape_dimer.escape_exit_num_dimer([Q,P],t_end,H))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 3.0
# 1.0
# 3.0
# 1.0

# %%
Tfp
# Out:
# 8-element Array{Float64,1}:
#   6.866269875952604
#   6.866269875952604
#  22.468577952673325
#  22.468577952673325
#  61.22169678118865
#  61.22169678118865
#  69.16017704629883
#  69.16017704629883

# %%
Q=.95
P=.65
figure()
Tf,Qf,hit_f,Tb,Qb,hit_b=Q1_trajectories(Q,P,t_end,H,true)
println(hit_f)
println(hit_b)

plot(Tf,Qf)
plot(-Tb,Qb)
Tfp,Qfp,hit_f,Tbp,Qbp,hit_b=Q1_trajectories(Q,P,t_end,H,false)
println(hit_f)
println(hit_b)

plot(Tfp,Qfp,".")
plot(-Tbp,Qbp,".");
q1, q2, p1, p2=forward_one(Q,P, t_end, H)
# Out:
# 3.0
# 1.0
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 3.0
# 1.0
# (-2.523135546819195e-17, -0.3794118793309957, 0.4829728137486918, -0.25902702905207575)

# %%
# Out:
# 4-element Array{Float64,1}:
#  -2.523135546819195e-17
#  -0.3794118793309957
#   0.4829728137486918
#  -0.25902702905207575

# %%
figure()
Tf,Qf,hit_f,Tb,Qb,hit_b=Q1_trajectories(q2,p2,t_end,H,true)
println(hit_f)
println(hit_b)

plot(Tf,Qf)
plot(-Tb,Qb)
Tfp,Qfp,hit_f,Tbp,Qbp,hit_b=Q1_trajectories(q2,p2,t_end,H,false)
println(hit_f)
println(hit_b)

plot(Tfp,Qfp,".")
plot(-Tbp,Qbp,".");
println(escape_dimer.escape_exit_num_dimer([q2,p2],t_end,H))
q1, q2, p1, p2=back_one(q2,p2, t_end, H)
# Out:
# 2.0
# 2.0
# 2.0
# 2.0
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (2.0, 2.0, [15.602308076720774, 15.602308076720774, 54.3554269061166, 54.3554269061166, 62.97334908077365, 62.97334908077365], [6.866269875952658, 6.866269875952658, 11.567031167627958, 11.567031167627958, 43.16405862379159, 43.16405862379159])
# (-3.3795490129847165e-17, 0.9500000000000045, 0.4206892118295473, 0.6499999999999909)

# %%
Tfp
# Out:
# 6-element Array{Float64,1}:
#   6.864081386915808
#   6.864081386915808
#  22.351376853970798
#  22.351376853970798
#  53.000281308541354
#  53.000281308541354

# %%
figure()
Tf,Qf,hit_f,Tb,Qb,hit_b=Q1_trajectories(q2,p2,t_end,H,true)
println(hit_f)
println(hit_b)

plot(Tf,Qf)
plot(-Tb,Qb)

Tfp,Qfp,hit_f,Tbp,Qbp,hit_b=Q1_trajectories(q2,p2,t_end,H,false)
println(hit_f)
println(hit_b)

plot(Tfp,Qfp,".")
plot(-Tbp,Qbp,".");
println(escape_dimer.escape_exit_num_dimer([q2,p2],t_end,H))


q1, q2, p1, p2=forward_one(q2,p2, t_end, H)
# Out:
# 2.0
# 2.0
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 2.0
# 2.0
# (2.0, 2.0, [15.60230807672346, 15.60230807672346, 54.35542689597135, 54.35542689597135, 62.33917739616907, 62.33917739616907], [6.866269875952884, 6.866269875952884, 11.567031167628587, 11.567031167628587, 44.2242850457615, 44.2242850457615])
# (1.22849060909112e-15, -0.05271208473145856, 0.5462767328427776, 0.28592319023666435)

# %%
figure()
Tf,Qf,hit_f,Tb,Qb,hit_b=Q1_trajectories(q2,p2,t_end,H,true)
println(hit_f)
println(hit_b)
Tfp,Qfp,hit_f,Tbp,Qbp,hit_b=Q1_trajectories(q2,p2,t_end,H,false)
plot(Tf,Qf)
plot(-Tb,Qb)
# q1, q2, p1, p2=forward_one(q2,p2, t_end, H)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1.0
# 3.0
# 1-element Array{PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fc0dc5edf60>

# %%
println(escape_dimer.escape_exit_num_dimer([q2,p2],t_end,H))
# Out:
# UndefVarError: q2 not defined
#
# Stacktrace:
#  [1] top-level scope at In[9]:1

# %%
include("back_one.jl")
# Out:
# back_one (generic function with 1 method)
